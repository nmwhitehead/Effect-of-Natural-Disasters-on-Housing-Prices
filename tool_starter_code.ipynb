# %% [markdown]
# # Natural Disasters & Avg. Real Estate Prices (PROJECT 5)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('./datasets/Sale_Prices_Zip.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5739 entries, 0 to 5738
# Columns: 121 entries, RegionID to 2019-09
# dtypes: float64(103), int64(17), object(1)
# memory usage: 5.3+ MB

# %%
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 3000)

# %%
data.tail()
# Out:
#       RegionID  RegionName       StateName  SizeRank  2010-01  2010-02  \
# 5734     65437       18347    Pennsylvania      5735      NaN      NaN
# 5735    399647       80951        Colorado      5736      NaN      NaN
# 5736     96852       92386      California      5737      NaN      NaN
# 5737     67463       22967        Virginia      5738      NaN      NaN
# 5738     69609       27927  North Carolina      5739      NaN      NaN
#
#       2010-03  2010-04  2010-05  2010-06  2010-07  2010-08  2010-09  2010-10  \
# 5734      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5735      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5736      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5737      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5738      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
data.shape
# Out:
# (5739, 121)

# %%
data.dtypes
# Out:
# RegionID        int64
# RegionName      int64
# StateName      object
# SizeRank        int64
# 2010-01       float64
# 2010-02       float64
# 2010-03       float64
# 2010-04       float64
# 2010-05       float64
# 2010-06       float64
# 2010-07       float64
# 2010-08       float64
# 2010-09       float64
# 2010-10       float64
# 2010-11       float64
# 2010-12       float64
# 2011-01       float64
# 2011-02       float64
# 2011-03       float64
# 2011-04       float64
# 2011-05       float64
# 2011-06       float64
# 2011-07       float64
# 2011-08       float64
# 2011-09       float64
# 2011-10       float64
# 2011-11       float64
# 2011-12       float64
# 2012-01       float64
# 2012-02       float64
# 2012-03       float64
# 2012-04       float64
# 2012-05       float64
# 2012-06       float64
# 2012-07       float64
# 2012-08       float64
# 2012-09       float64
# 2012-10       float64
# 2012-11       float64
# 2012-12       float64
# 2013-01       float64
# ...

# %%
data.shape
# Out:
# (5739, 121)

# %%
data.rename(columns={'RegionName':'zip'}, inplace=True)

# %%
data.loc[data['zip'].isin([77494])]
# Out:
#    RegionID    zip StateName  SizeRank  2010-01  2010-02  2010-03  2010-04  \
# 3     91982  77494     Texas         4      NaN      NaN      NaN      NaN
#
#    2010-05  2010-06  2010-07  2010-08  2010-09  2010-10  2010-11  2010-12  \
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2011-01  2011-02  2011-03  2011-04  2011-05  2011-06  2011-07  2011-08  \
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2011-09  2011-10  2011-11  2011-12  2012-01  2012-02  2012-03  2012-04  \
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    2012-05   2012-06   2012-07   2012-08   2012-09   2012-10   2012-11  \
# 3      NaN  267900.0  259000.0  255900.0  256600.0  268200.0  267600.0
#
#     2012-12   2013-01   2013-02   2013-03   2013-04   2013-05   2013-06  \
# 3  262200.0  250400.0  243500.0  251300.0  259700.0  270400.0  269700.0
#
# ...

# %%
data.head()
# Out:
#    RegionID    zip StateName  SizeRank  2010-01  2010-02  2010-03  2010-04  \
# 0     61639  10025  New York         1      NaN      NaN      NaN      NaN
# 1     84654  60657  Illinois         2      NaN      NaN      NaN      NaN
# 2     61637  10023  New York         3      NaN      NaN      NaN      NaN
# 3     91982  77494     Texas         4      NaN      NaN      NaN      NaN
# 4     84616  60614  Illinois         5      NaN      NaN      NaN      NaN
#
#    2010-05  2010-06  2010-07  2010-08  2010-09  2010-10  2010-11  2010-12  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
def finding_row(zipcode):
    a = pd.DataFrame(data.loc[(data.zip == zipcode)])
    return a

# %%
finding_row(78660)
# Out:
#     RegionID    zip StateName  SizeRank  2010-01  2010-02  2010-03  2010-04  \
# 11     92593  78660     Texas        12      NaN      NaN      NaN      NaN
#
#     2010-05  2010-06  2010-07  2010-08  2010-09  2010-10  2010-11  2010-12  \
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     2011-01  2011-02  2011-03  2011-04  2011-05  2011-06  2011-07  2011-08  \
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     2011-09  2011-10  2011-11  2011-12  2012-01  2012-02  2012-03  2012-04  \
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     2012-05  2012-06  2012-07  2012-08  2012-09  2012-10  2012-11  2012-12  \
# 11      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#     2013-01  2013-02   2013-03   2013-04   2013-05   2013-06   2013-07  \
# 11      NaN      NaN  174600.0  183300.0  191800.0  203400.0  207400.0
#
# ...

# %%
def finding_city(zipcode):
    a = pd.DataFrame(data.loc[(data.zip == zipcode)])
    c = print('The state for this zipcode is:', a['StateName'])
    return c

# %%
finding_city(78660);
# Out:
# The state for this zipcode is: 11    Texas
# Name: StateName, dtype: object

# %% [markdown]
# # ONLY DATES

# %%
dates= data.iloc[:, 5:-1]

# %%
dates.insert(0,'Zip', data['zip'], True)

# %%
dates
# Out:
#         Zip  2010-02  2010-03  2010-04  2010-05  2010-06  2010-07  2010-08  \
# 0     10025      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1     60657      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2     10023      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3     77494      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4     60614      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...     ...      ...      ...      ...      ...      ...      ...      ...
# 5734  18347      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5735  80951      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5736  92386      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5737  22967      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 5738  27927      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# ...

# %%
dates.set_index("Zip", inplace=True)

# %%
dates.columns
# Out:
# Index(['2010-02', '2010-03', '2010-04', '2010-05', '2010-06', '2010-07',
#        '2010-08', '2010-09', '2010-10', '2010-11',
#        ...
#        '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04',
#        '2019-05', '2019-06', '2019-07', '2019-08'],
#       dtype='object', length=115)

# %%
# a=dates[dates.columns.difference(['N_Disasters'])]
# len(a)

# %%
def graph(zipcodes):
    plt.figure(figsize=(15,10));
    plt.title(("Price changes for households in zipcodes"), fontsize=30);
    plt.xlabel('Years', fontsize=20);
    plt.ylabel('Average House Price', fontsize=20);
    
    for zipcode in zipcodes:
        
        
        #plt.xticks([6, 18, 30, 42, 54, 66, 78, 90], ['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']);
        #data.loc[data['zip'].isin([zipcode])]
        #for index, row in dates.iterrows():
        #ax.set_xticks(ax.get_xticks()[::2])
        plt.xticks(rotation=90)
        plt.xticks(np.arange(0, 1000, step=6))
        plt.plot(dates.loc[zipcode, '2010-02':'2019-08'])
        #plt.axvline(46, label='Unnamed Storm/Flood', linestyle='dashdot', c='b')
        plt.axvline('2016-09', label='Hurricane Mathew', linestyle='dashed', c='r')
        plt.axvline('2017-09', label='Hurricane Irma', linestyle='dashed', c='m')
        plt.axvline('2018-09', label='Hurricane Florence', linestyle='dashed', c='g')
        z= (100*((dates.loc[zipcode, '2010-01':'2019-09'].pct_change(axis=0).abs().max())))
        print(f'The largest percentage change (month-to-month) in {zipcode} was of around %', round(z, 2))
        plt.legend()
    
    return plt.figure

# %%
graph([27927])
# Out:
# The largest percentage change (month-to-month) in 27927 was of around % 24.99
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
pd.DataFrame(data.loc[(data.zip == 60614), '2019-09'] ).describe()
# Out:
#         2019-09
# count       1.0
# mean   474500.0
# std         NaN
# min    474500.0
# 25%    474500.0
# 50%    474500.0
# 75%    474500.0
# max    474500.0

# %% [markdown]
# ### Mean, median, min, max, average per zipcode

# %%
def descriptive_statistics(zipcode):
    z = pd.DataFrame(data.loc[(data.zip == zipcode), '2019-09'] ).describe()
    return z

# %%
descriptive_statistics(90210)
# Out:
#        2019-09
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
dates_pct = dates.pct_change(axis=1)

# %%
zipcodex= 27927
ziprow= dates_pct.loc[zipcodex,:]

# %%
ziprow
# Out:
# 2010-02         NaN
# 2010-03         NaN
# 2010-04         NaN
# 2010-05         NaN
# 2010-06         NaN
# 2010-07         NaN
# 2010-08         NaN
# 2010-09         NaN
# 2010-10         NaN
# 2010-11         NaN
# 2010-12         NaN
# 2011-01         NaN
# 2011-02         NaN
# 2011-03         NaN
# 2011-04         NaN
# 2011-05         NaN
# 2011-06         NaN
# 2011-07         NaN
# 2011-08         NaN
# 2011-09         NaN
# 2011-10         NaN
# 2011-11         NaN
# 2011-12         NaN
# 2012-01         NaN
# 2012-02         NaN
# 2012-03         NaN
# 2012-04    0.249949
# 2012-05   -0.004541
# 2012-06   -0.063539
# 2012-07   -0.156228
# 2012-08    0.014227
# 2012-09   -0.105713
# 2012-10    0.055467
# 2012-11   -0.001077
# 2012-12    0.146615
# 2013-01   -0.048326
# 2013-02   -0.060067
# 2013-03    0.029220
# 2013-04   -0.045956
# 2013-05    0.043674
# 2013-06    0.035077
# 2013-07    0.099485
# 2013-08   -0.024513
# 2013-09   -0.141168
# 2013-10   -0.002367
# ...

# %%
ziprow.abs().argmax()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# '2012-04'

# %%
dates_pct.columns
# Out:
# Index(['2010-02', '2010-03', '2010-04', '2010-05', '2010-06', '2010-07',
#        '2010-08', '2010-09', '2010-10', '2010-11',
#        ...
#        '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04',
#        '2019-05', '2019-06', '2019-07', '2019-08'],
#       dtype='object', length=115)

# %%
def pct(zipcode):
    b = 100*(dates_pct.loc[zipcode, :].abs().max()) #.pct_change().abs().max()
    b= round(b,2)
    return b

# %%
pct(60614)
# Out:
# 25.66

# %% [markdown]
# # Only hurracane Matthew

# %%
matthew= data.iloc[:, -38:-35]

# %%
matthew.insert(0,'Zip', data['zip'], True)
matthew.set_index("Zip", inplace=True)
matthewpct = matthew.pct_change(axis=1)
matthewpctx = matthewpct[matthewpct < 0]
matthewpctx
# Out:
#        2016-08   2016-09   2016-10
# Zip
# 10025      NaN -0.074013 -0.014252
# 60657      NaN -0.027221 -0.053608
# 10023      NaN -0.009227 -0.048760
# 77494      NaN       NaN -0.005639
# 60614      NaN       NaN       NaN
# ...        ...       ...       ...
# 18347      NaN       NaN       NaN
# 80951      NaN       NaN       NaN
# 92386      NaN -0.012623 -0.041193
# 22967      NaN       NaN       NaN
# 27927      NaN       NaN       NaN
#
# [5739 rows x 3 columns]

# %%
matthewpctx.abs().sort_values('2016-10', ascending=False).head()
# Out:
#        2016-08   2016-09   2016-10
# Zip
# 7105       NaN       NaN  0.206380
# 19809      NaN       NaN  0.187657
# 17512      NaN       NaN  0.178231
# 44718      NaN  0.009786  0.169412
# 2865       NaN  0.049451  0.165590

# %% [markdown]
# ### List of zipcodes during huracane matthew with larger changes in prices:
# 7105, 19809, 17512, 44718, 2865

# %% [markdown]
# # Only Irma

# %%
irma= data.iloc[:, -26:-23]

# %%
irma.insert(0,'Zip', data['zip'], True)
irma.set_index("Zip", inplace=True)
irmapct = irma.pct_change(axis=1)
irmapctx = irmapct[irmapct < 0]
irmapctx
# Out:
#        2017-08   2017-09   2017-10
# Zip
# 10025      NaN -0.030808 -0.083924
# 60657      NaN       NaN       NaN
# 10023      NaN -0.016648 -0.003535
# 77494      NaN       NaN       NaN
# 60614      NaN -0.059838 -0.010518
# ...        ...       ...       ...
# 18347      NaN -0.032577       NaN
# 80951      NaN       NaN       NaN
# 92386      NaN       NaN       NaN
# 22967      NaN -0.052919 -0.054724
# 27927      NaN       NaN -0.086417
#
# [5739 rows x 3 columns]

# %%
irmapctx.abs().sort_values('2017-10', ascending=False).head()
# Out:
#        2017-08   2017-09   2017-10
# Zip
# 46055      NaN  0.057785  0.255600
# 80498      NaN       NaN  0.155591
# 66227      NaN  0.037709  0.151427
# 30513      NaN       NaN  0.148824
# 32428      NaN       NaN  0.147306

# %% [markdown]
# ### List of zipcodes during huracane irma with larger changes in prices:
# 46055, 80498, 66227, 30513, 32428

# %% [markdown]
# # Only hurricane Florence

# %%
florence= data.iloc[:, -14:-11]

# %%
florence.insert(0,'Zip', data['zip'], True)
florence.set_index("Zip", inplace=True)
florencepct = florence.pct_change(axis=1)
florencepctx = florencepct[florencepct < 0]
florencepctx
# Out:
#        2018-08   2018-09  2018-10
# Zip
# 10025      NaN       NaN      NaN
# 60657      NaN -0.006155      NaN
# 10023      NaN       NaN      NaN
# 77494      NaN -0.041371 -0.01418
# 60614      NaN       NaN      NaN
# ...        ...       ...      ...
# 18347      NaN -0.024762      NaN
# 80951      NaN -0.002202      NaN
# 92386      NaN -0.029279      NaN
# 22967      NaN -0.119300      NaN
# 27927      NaN -0.142683      NaN
#
# [5739 rows x 3 columns]

# %%
florencepctx.abs().sort_values('2018-10', ascending=False).head()
# Out:
#        2018-08   2018-09   2018-10
# Zip
# 20678      NaN       NaN  0.228070
# 33016      NaN  0.013705  0.186600
# 6820       NaN  0.052255  0.174079
# 1543       NaN  0.159916  0.172857
# 97601      NaN       NaN  0.163402

# %% [markdown]
# ### List of zipcodes during huracane Florence with larger changes in prices:
# 20678, 33016, 6820	, 1543, 97601

# %% [markdown]
# # FEMA

# %%
fema= pd.read_csv('./datasets/fema_zip_dataset.csv')
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fema.rename(columns={'Zip Code':'zipcode'}, inplace=True)

# %%
fema.head()
# Out:
#    Unnamed: 0 State Incident Type  Year zipcode
# 0           0    AL       Tornado  2019   36551
# 1           1    AL       Tornado  2019   36146
# 2           2    AL       Tornado  2019   35005
# 3           3    AL       Tornado  2019   35243
# 4           4    AL       Tornado  2019   36852

# %%
fema.drop('State', axis=1, inplace=True)

# %%
fema.head()
# Out:
#    Unnamed: 0 Incident Type  Year zipcode
# 0           0       Tornado  2019   36551
# 1           1       Tornado  2019   36146
# 2           2       Tornado  2019   35005
# 3           3       Tornado  2019   35243
# 4           4       Tornado  2019   36852

# %%
fema.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
fema.shape
# Out:
# (223431, 3)

# %%
fema.head()
# Out:
#   Incident Type  Year zipcode
# 0       Tornado  2019   36551
# 1       Tornado  2019   36146
# 2       Tornado  2019   35005
# 3       Tornado  2019   35243
# 4       Tornado  2019   36852

# %%
fema.set_index('zipcode', inplace=True)

# %%
def fema_check(zipcode):
    fema_match = zipcode in fema.index
    
    if zipcode in fema.index:
        print('Go ahead')
    else:
        print('Error: Zipcode not in the Fema dataset')
        #return render_template('form.html', error_message=error_message)

# %%
fema_check(36551)
# Out:
# Go ahead

# %%
def finding_row(zipcode):
    if pd.DataFrame(fema.loc[(fema.zipcode == zipcode)]).empty:
        a = 'There have been no natural disasters in this zipcode' 
    else:
        a= pd.DataFrame(fema.loc[(fema.zipcode == zipcode)])
    return a

# %%
if pd.DataFrame(fema.loc[(fema.index == 27927)]).empty:
    a = 'There have been no natural disasters in this zipcode' 
else:
    a= pd.DataFrame(fema.loc[(fema.index == 27927)])
a
# Out:
#             Incident Type  Year
# zipcode
# 27927           Hurricane  2018
# 27927     Severe Storm(s)  2018
# 27927           Hurricane  2016
# 27927    Severe Ice Storm  2014
# 27927               Flood  2013
# 27927       Mud/Landslide  2013
# 27927           Hurricane  2011
# 27927                Fire  2011
# 27927     Severe Storm(s)  2011
# 27927     Severe Storm(s)  2010
# 27927           Hurricane  2010

# %%
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 30000)

# %%
#fema

# %%
len(fema.index.unique())
# Out:
# 24428

# %%
len(dates.index.unique())
# Out:
# 5739

# %%
pd.DataFrame(dates.index.unique()).head()
# Out:
#      Zip
# 0  10025
# 1  60657
# 2  10023
# 3  77494
# 4  60614

# %%
pd.DataFrame(fema.index.unique()).head()
# Out:
#   zipcode
# 0   36551
# 1   36146
# 2   35005
# 3   35243
# 4   36852

# %%
v = pd.merge(fema, dates, how = 'inner', left_index=True,
    right_index=True)

# %%
v.index.unique()
# Out:
# Int64Index([ 1420,  2769,  6001,  6010,  6032,  6033,  6037,  6040,  6042,
#              6062,
#             ...
#             98944, 99353, 99354, 99502, 99507, 99515, 99516, 99518, 99611,
#             99669],
#            dtype='int64', length=2586)

# %%
v.shape
# Out:
# (28226, 117)

# %%
len(v.index.unique()) # only 4083 zipcdoes appear in both datasets
# Out:
# 2586

# %% [markdown]
# # Errors

# %%
def errors(zipcode):
    if zipcode in dates.index:
        print('Go ahead')
    else:
        print('Error: There is no information about that zipcode.')
        #return render_template('form.html', error_message=error_message)

# %%
errors(2048)
# Out:
# Go ahead

# %% [markdown]
# # The End
